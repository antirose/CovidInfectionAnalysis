# %%
import pandas as pd

# %%
df=pd.read_csv ("./CovidFinalGender.csv")

# %%
len(df.columns)
# Out:
# 10

# %%
df
# Out:
#                    State    Women      Men  Total Infection W_M   \
# 0                Alabama   439375   405576                844951
# 1                 Alaska    70799    73374                144173
# 2                Arizona   649245   608050               1257295
# 3               Arkansas   275732   245681                521413
# 4             California  2423900  2285254               4709154
# 5               Colorado   409450   396711                806161
# 6            Connecticut   216368   200482                416850
# 7               Delaware    79984    69847                149831
# 8   District of Columbia    34397    31069                 65466
# 9                Florida  1196209  1069736               2265945
# 10               Georgia   681256   586834               1268090
# 11                Hawaii    40482    43674                 84156
# 12                 Idaho   159058   145163                304221
# ...

# %%
df.iloc[0].to_frame().T
# Out:
#      State   Women     Men Total Infection W_M  Women in Percentage  \
# 0  Alabama  439375  405576               844951                  52
#
#   Men In Percentage Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0                48        NaN        NaN        NaN        NaN

# %%
df.iloc[1].to_frame().T.to_csv ('test.csv',index=False)

# %%
df.iloc[2].to_frame().T.to_csv ('test2.csv',index=False)
