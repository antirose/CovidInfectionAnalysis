# %%
# Add the Pandas dependency.
import pandas as pd

# %%
gender_data_to_load = "./Cases by Gender.csv"
covid_usa_to_load = "./covid19_united_states.csv"
race_ethnicity_to_load = "./Race and Ethnicity.csv"

# %%
gender_data_df = pd.read_csv(gender_data_to_load)
covid_usa_df = pd.read_csv(covid_usa_to_load)
race_ethnicity_df = pd.read_csv(race_ethnicity_to_load)

# %%
gender_data_df
# Out:
#          State               Unnamed: 1 27-Nov-21
# 0      Alabama                   Women        NaN
# 1      Alabama                     Men        NaN
# 2      Alabama    Number of Cases (Men)       NaN
# 3      Alabama  Number of Cases (Women)       NaN
# 4       Alaska                   Women         49
# ..         ...                      ...       ...
# 207  Wisconsin  Number of Cases (Women)   445,490
# 208    Wyoming                   Women         40
# 209    Wyoming                     Men         38
# 210    Wyoming    Number of Cases (Men)    41,536
# 211    Wyoming  Number of Cases (Women)    43,651
#
# [212 rows x 3 columns]

# %%
covid_usa_df.head(10)
# Out:
#   State/Territory/Federal Entity  Total Doses Delivered  \
# 0                  United States              696801055
# 1                         Alaska                1464865
# 2                        Alabama                9344040
# 3                       Arkansas                5921480
# 4                 American Samoa                 110410
# 5                        Arizona               14211920
# 6              Bureau of Prisons                 336130
# 7                     California               86699025
# 8                       Colorado               11965375
# 9                    Connecticut                8381735
#
#    Doses Delivered per 100K  18+ Doses Delivered per 100K  \
# 0                  209874.0                      269806.0
# 1                  200243.0                      265585.0
# 2                  190571.0                      244937.0
# 3                  196218.0                      255495.0
# ...

# %%
race_ethnicity_df.head(10)
# Out:
#        Date State  Cases_Total  Cases_White  Cases_Black  Cases_Latinx  \
# 0  20210307    AK      59332.0      18300.0       1499.0           NaN
# 1  20210307    AL     499819.0     160347.0      82790.0           NaN
# 2  20210307    AR     324818.0     207596.0      50842.0           NaN
# 3  20210307    AS          NaN          NaN          NaN           NaN
# 4  20210307    AZ     826454.0     308453.0      25775.0      244539.0
# 5  20210307    CA    3501394.0     546630.0     111279.0     1509103.0
# 6  20210307    CO     435762.0     181669.0      12637.0      119224.0
# 7  20210307    CT     285330.0      85469.0      19651.0       41523.0
# 8  20210307    DC      41419.0      10708.0      20164.0           NaN
# 9  20210307    DE      88354.0      42730.0      19768.0       14532.0
#
#    Cases_Asian  Cases_AIAN  Cases_NHPI  Cases_Multiracial  ...  Tests_Latinx  \
# 0       2447.0     12238.0      1508.0             4453.0  ...           NaN
# ...

# %%
covid_usa_df.notnull()
# Out:
#     State/Territory/Federal Entity  Total Doses Delivered  \
# 0                             True                   True
# 1                             True                   True
# 2                             True                   True
# 3                             True                   True
# 4                             True                   True
# ..                             ...                    ...
# 59                            True                   True
# 60                            True                   True
# 61                            True                   True
# 62                            True                   True
# 63                            True                   True
#
#     Doses Delivered per 100K  18+ Doses Delivered per 100K  \
# 0                       True                          True
# 1                       True                          True
# 2                       True                          True
# ...
