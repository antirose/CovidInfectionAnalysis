# %%
import pandas as pd

# %%
df=pd.read_csv ("./FinalVax.csv")

# %%
len(df.columns)
# Out:
# 10

# %%
df
# Out:
#                    State  Total Doses Delivered  \
# 0                Alabama                9344040
# 1                 Alaska                1464865
# 2                Arizona               14211920
# 3               Arkansas                5921480
# 4             California               86699025
# 5               Colorado               11965375
# 6            Connecticut                8381735
# 7               Delaware                2243655
# 8   District of Columbia                1796405
# 9                Florida               46078085
# 10               Georgia               20870895
# 11                Hawaii                3337580
# 12                 Idaho                3247090
# 13              Illinois               26377145
# 14               Indiana               12771980
# 15                  Iowa                6318955
# 16                Kansas                5790715
# 17              Kentucky                8498075
# ...

# %%
df.iloc[1].to_frame().T
# Out:
#     State Total Doses Delivered  \
# 1  Alaska               1464865
#
#   Total Doses Administered by State where Administered  \
# 1                                            1108025
#
#   People with at least One Dose by State of Residence  \
# 1                                             504539
#
#   Percent of Total Pop with at least One Dose by State of Residence  \
# 1                                                 69
#
#   People Fully Vaccinated by State of Residence  \
# 1                                        449359
#
#   Percent of Total Pop Fully Vaccinated by State of Residence  \
# 1                                                 61
#
#   Percent of Total Pop with over 1 Dose by State of Residence  \
# 1                                                 69
#
#   People who have received a booster dose  \
# 1                                  188122
#
#   Percent of fully vaccinated people with booster doses
# 1                                                 42

# %%
df.iloc[1].to_frame().T.to_csv ('test.csv',index=False)

# %%
df.iloc[2].to_frame().T.to_csv ('test2.csv',index=False)
